# %% [markdown]
# ## Healthy Life Expectancy (HALE) at 60 (years)

# %%
# %matplotlib notebook

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint
import requests
import json
import os
import csv

# %%
# read in the countries analyzed
countries_df = pd.read_csv("output_data/happy_countries.csv", index_col="Country")
country_num = {len(countries_data_df)}

# %%
countries_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [Switzerland, Iceland, Denmark, Norway, Canada, Finland, Netherlands, Sweden, New Zealand, Australia, Israel, Costa Rica, Austria, Mexico, United States, Brazil, Ireland, Belgium, United Kingdom, Venezuela, Singapore, Panama, Germany, Chile, France, Argentina, Uruguay, Colombia, Thailand, Saudi Arabia, Spain, Malta, El Salvador, Uzbekistan, Slovakia, Japan, South Korea, Ecuador, Bahrain, Italy, Bolivia, Moldova, Paraguay, Kazakhstan, Slovenia, Lithuania, Nicaragua, Peru, Poland, Malaysia, Croatia, Russia, Jamaica, Cyprus, Algeria, Kosovo, Mauritius, Estonia, Indonesia, Vietnam, Turkey, Kyrgyzstan, Nigeria, Pakistan, Jordan, Montenegro, China, Zambia, Romania, Serbia, Portugal, Latvia, Philippines, Morocco, Albania, Bosnia and Herzegovina, Dominican Republic, Mongolia, Greece, Lebanon, Hungary, Honduras, Tajikistan, Tunisia, Bangladesh, Iran, Ukraine, Iraq, South Africa, Ghana, Zimbabwe, India, Nepal, Ethiopia, Sierra Leone, Kenya, Armenia, Myanmar, Georgia, Malawi, ...]
#
# [116 rows x 0 columns]

# %%
# define variables, lists
# years of data for analysis
year_list = ['2015', '2016', '2017', '2018', '2019', '2022'] # individual years included in the data
test_list = ['2015-2019', '2022'] # years for presentation

# project happiness survey categories
categories = ['Happiness Score', 'Family', 'Health', 'Freedom', 'Perceptions of Corruption', 'Generosity']

# lists to hold the data from the json file
  ## year, value
hale_data = []

# %%
# set the api url, codes, and filters (no api key required)
##  World Heath Organization Data  ##
url = 'http://apps.who.int/gho/athena/api/'
who_data = 'GHO'
who_code = 'WHOSIS_000007'

for i, country in enumerate(countries_df):

    # create url for json request
    base_url = f'{url}{who_data}/{who_code}.json'
    #try:
        # Parse the JSON and retrieve data
        
    data = requests.get(base_url).json()
    data
#     # parse out to get the years of life left in retirement

#       #  hale_year = data['fact']['Dim']['category']['REGION']  # country  ie: "Americas"
#         hale_year = data['fact']['Dim']['category']['YEAR']    # year  ie: "2019"
#       #  hale_gho = data['Dims']['category']['GHO']    # hale at 60 (years)  ie: "Healthy life expectancy (HALE) at age 60 (years)"
#       # hale_year = data[]

#     #      hale_data.append({'Country': country, 
#     #                       'Hale Year': hale_year, 
#     #                       'Hale Value': hale_value
#     #                      })   
#         # Append the City information into city_data list
#         hale_data.append({'Country': country, 
#                           'Hale Year': hale_year, 
#                          })
#         print(f'{hale_year} {country}')
#     except:
#         print(f'(countries_df[countries_df.columns[0] not found)')
#        # df2 = df[df.columns[0]]
#         pass

# %%
countries_df = countries_df.reset_index()  # make sure indexes pair with number of rows

for index, row in countries_df.iterrows():
    print(row['Country'])
# Out:
# Switzerland
# Iceland
# Denmark
# Norway
# Canada
# Finland
# Netherlands
# Sweden
# New Zealand
# Australia
# Israel
# Costa Rica
# Austria
# Mexico
# United States
# Brazil
# Ireland
# Belgium
# United Kingdom
# Venezuela
# Singapore
# Panama
# Germany
# Chile
# France
# Argentina
# Uruguay
# Colombia
# Thailand
# Saudi Arabia
# Spain
# Malta
# El Salvador
# Uzbekistan
# Slovakia
# Japan
# South Korea
# Ecuador
# Bahrain
# Italy
# Bolivia
# Moldova
# Paraguay
# Kazakhstan
# Slovenia
# Lithuania
# Nicaragua
# Peru
# Poland
# Malaysia
# Croatia
# Russia
# Jamaica
# Cyprus
# Algeria
# Kosovo
# Mauritius
# Estonia
# Indonesia
# Vietnam
# Turkey
# Kyrgyzstan
# Nigeria
# Pakistan
# Jordan
# Montenegro
# China
# Zambia
# Romania
# Serbia
# Portugal
# Latvia
# Philippines
# Morocco
# Albania
# Bosnia and Herzegovina
# Dominican Republic
# Mongolia
# Greece
# Lebanon
# Hungary
# Honduras
# Tajikistan
# Tunisia
# Bangladesh
# Iran
# Ukraine
# Iraq
# South Africa
# Ghana
# Zimbabwe
# India
# Nepal
# Ethiopia
# Sierra Leone
# Kenya
# Armenia
# Myanmar
# Georgia
# Malawi
# Sri Lanka
# Cameroon
# Bulgaria
# Egypt
# Mali
# Uganda
# Senegal
# Gabon
# Cambodia
# Tanzania
# Guinea
# Ivory Coast
# Burkina Faso
# Afghanistan
# Benin
# Togo

# %%
# set the api url, codes, and filters (no api key required)
##  World Heath Organization Data  ##
url = 'http://apps.who.int/gho/athena/api/'
who_data = 'GHO'
who_code = 'WHOSIS_000007'
who_profile = 'simple'

my_country = 'Anogola'


#index = 0
    #for index, row in countries_df.iterrows():
        

    
    # create url for json request
base_url = f'{url}{who_data}/{who_code}.json?profile={who_profile}'

data = requests.get(base_url).json()
#pprint(data)
#https://apps.who.int/gho/athena/api/GHO/WHOSIS_000007.json?profile=simple

    index += 1
# Out:
# {'dimension': [{'display': 'Indicator', 'label': 'GHO'},
#                {'display': 'PUBLISH STATES', 'label': 'PUBLISHSTATE'},
#                {'display': 'Year', 'label': 'YEAR'},
#                {'display': 'WHO region', 'label': 'REGION'},
#                {'display': 'World Bank income group',
#                 'label': 'WORLDBANKINCOMEGROUP'},
#                {'display': 'Country', 'label': 'COUNTRY'},
#                {'display': 'Sex', 'label': 'SEX'}],
#  'fact': [{'Value': '10.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '11.1',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '11.5',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '11.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '10.1',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '10.7',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '10.9',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '10.6',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '10.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '10.9',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '11.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '10.8',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '9.7',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '10.8',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '11.3',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '11.6',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '11.8',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '12.9',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.6',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '13.7',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '10.7',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '11.9',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '12.4',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '12.6',
#            'dim': {'COUNTRY': 'Angola',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.5',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '15.7',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '15.9',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '15.9',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '16.7',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '17.7',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '17.5',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '17.3',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '15.0',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '16.7',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '16.7',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '16.6',
#            'dim': {'COUNTRY': 'Albania',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.3',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '13.9',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '13.7',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '14.1',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '14.0',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '14.7',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '14.9',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '15.3',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '13.6',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '14.1',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '14.1',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '14.5',
#            'dim': {'COUNTRY': 'United Arab Emirates',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.9',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '14.4',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '14.7',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '14.8',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '17.2',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '17.4',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '17.6',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '17.6',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '15.6',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '16.0',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '16.2',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '16.3',
#            'dim': {'COUNTRY': 'Argentina',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.3',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '13.2',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '13.6',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '14.2',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '15.5',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '15.7',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '16.2',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '16.9',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '14.5',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '14.6',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '15.0',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '15.7',
#            'dim': {'COUNTRY': 'Armenia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '14.9',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '14.8',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '15.1',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '15.3',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '16.5',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '16.8',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '16.3',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '16.3',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '15.7',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '15.8',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '15.8',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '15.8',
#            'dim': {'COUNTRY': 'Antigua and Barbuda',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Americas',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '16.1',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '17.5',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '17.9',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '18.2',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '18.4',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '19.3',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '19.4',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '19.7',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '17.3',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '18.4',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '18.6',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '19.0',
#            'dim': {'COUNTRY': 'Australia',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '15.1',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '16.3',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '16.6',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '17.2',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '18.0',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '19.1',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '19.1',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '19.4',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '16.7',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '17.8',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '17.9',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '18.3',
#            'dim': {'COUNTRY': 'Austria',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '12.1',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '12.0',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '12.1',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '12.4',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '13.9',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '13.7',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.9',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '14.2',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '13.1',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '12.9',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '13.1',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '13.4',
#            'dim': {'COUNTRY': 'Azerbaijan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '9.1',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '11.0',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '11.5',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '11.8',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '10.6',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '12.8',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.3',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '13.5',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '9.9',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '12.0',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '12.4',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '12.7',
#            'dim': {'COUNTRY': 'Burundi',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '15.0',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '16.3',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '16.8',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '17.2',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '17.9',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '18.6',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '18.8',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '19.1',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '16.6',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '17.5',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '17.9',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '18.2',
#            'dim': {'COUNTRY': 'Belgium',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '11.1',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '11.6',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '11.9',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '12.3',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '12.9',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '13.3',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.4',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Africa',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '13.7',
#            'dim': {'COUNTRY': 'Benin',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
# ...
#                    'YEAR': '2019'}},
#           {'Value': '12.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '13.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '14.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '12.0',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '13.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '13.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '13.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'South-East Asia',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.4',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '14.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '15.4',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '15.8',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '16.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '17.5',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '17.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '18.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '15.0',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '16.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '16.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '17.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Europe',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '12.5',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '13.0',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '13.0',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '13.4',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '13.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '13.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '13.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '13.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '12.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '13.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '13.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '13.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '14.5',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2010'}},
#           {'Value': '15.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2015'}},
#           {'Value': '15.4',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Male',
#                    'YEAR': '2019'}},
#           {'Value': '15.8',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2000'}},
#           {'Value': '16.9',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2010'}},
#           {'Value': '17.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2015'}},
#           {'Value': '17.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Female',
#                    'YEAR': '2019'}},
#           {'Value': '14.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},
#           {'Value': '15.7',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2010'}},
#           {'Value': '16.3',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2015'}},
#           {'Value': '16.5',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Western Pacific',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2019'}},
#           {'Value': '13.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Male',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2000'}},
#           {'Value': '14.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Male',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2010'}},
#           {'Value': '14.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Male',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2015'}},
#           {'Value': '14.8',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Male',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2019'}},
#           {'Value': '15.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Female',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2000'}},
#           {'Value': '16.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Female',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2010'}},
#           {'Value': '16.4',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Female',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2015'}},
#           {'Value': '16.6',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Female',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2019'}},
#           {'Value': '14.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Both sexes',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2000'}},
#           {'Value': '15.1',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Both sexes',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2010'}},
#           {'Value': '15.5',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Both sexes',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2015'}},
#           {'Value': '15.8',
#            'dim': {'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Global',
#                    'SEX': 'Both sexes',
#                    'WORLDBANKINCOMEGROUP': 'Global',
#                    'YEAR': '2019'}}]}

# %%
# 'fact': [{'Value': '10.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Male',
#                    'YEAR': '2000'}},
#           {'Value': '11.1',


#   	  {'Value': '10.2',
#            'dim': {'COUNTRY': 'Afghanistan',
#                    'GHO': 'Healthy life expectancy (HALE) at age 60 (years)',
#                    'PUBLISHSTATE': 'Published',
#                    'REGION': 'Eastern Mediterranean',
#                    'SEX': 'Both sexes',
#                    'YEAR': '2000'}},

# %%
# parse out to get the years of life left in retirement


hale_country = hale_info['Dim']['category']['REGION']  # country  ie: "Americas"
hale_year = hale_info['Dim']['category']['YEAR']    # year  ie: "2019"
# hale_gho = hale_info['dims']['GHO']    # hale at 60 (years)  ie: "Healthy life expectancy (HALE) at age 60 (years)"
# hale_sex = hale_info['dims']['SEX']    # both sexes  ie: "Both sexes"
hale_value = hale_info['Dim']['category']['Value']

# append the hale data into the hale_list
hale_list.append({'Country': hale_country,
                  'Data Year': hale_year,
                  'Hale Value': hale_value
                 })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27796\988026126.py in <module>
#       2
#       3
# ----> 4 hale_country = hale_info['Dim'][0]['category']['REGION']  # country  ie: "Americas"
#       5 hale_year = hale_info['Dim']['category']['YEAR']    # year  ie: "2019"
#       6 # hale_gho = hale_info['dims']['GHO']    # hale at 60 (years)  ie: "Healthy life expectancy (HALE) at age 60 (years)"
#
# KeyError: 'Dim'

# %%
data = pd.read_json('http://apps.who.int/gho/athena/api/GHO/WHOSIS_000007.json')
pprint(data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27796\1360948465.py in <module>
#       1 data = pd.read_json(
# ----> 2                     'http://apps.who.int/gho/athena/api/GHO/WHOSIS_000007.json'
#       3                     )
#       4 pprint(data)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     583     compression = infer_compression(path_or_buf, compression)
#     584     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 585         path_or_buf, encoding=encoding, compression=compression
#     586     )
#     587
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     170
#     171     if isinstance(filepath_or_buffer, str) and is_url(filepath_or_buffer):
# --> 172         req = urlopen(filepath_or_buffer)
#     173         content_encoding = req.headers.get("Content-Encoding", None)
#     174         if content_encoding == "gzip":
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\anaconda3\envs\PythonData\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden
