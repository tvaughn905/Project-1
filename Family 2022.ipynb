# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
import json
from scipy import stats

# Store filepath in a variable
file = "Output_data/Happiness_df.csv"

# %%
original_df = pd.read_csv(file)
original_df
# Out:
#      Index       Country  Rank (2015)  Happiness Score (2015)  Family (2015)  \
# 0        0   Switzerland          1.0                   7.587        1.34951
# 1        1       Iceland          2.0                   7.561        1.40223
# 2        2       Denmark          3.0                   7.527        1.36058
# 3        3        Norway          4.0                   7.522        1.33095
# 4        4        Canada          5.0                   7.427        1.32261
# ..     ...           ...          ...                     ...            ...
# 111    132   Ivory Coast        151.0                   3.655        0.77115
# 112    133  Burkina Faso        152.0                   3.587        0.85188
# 113    134   Afghanistan        153.0                   3.575        0.30285
# 114    136         Benin        155.0                   3.340        0.35386
# 115    139          Togo        158.0                   2.839        0.13995
#
# ...

# %%
Social_support_df = original_df[["Country", "Explained by: Social support"]]
Social_support_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Social_support_df = original_df[["Country", "Explained by: Social support"]]
#       2 Social_support_df.head()
#
# File ~\Anaconda\envs\PythonDAta\lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~\Anaconda\envs\PythonDAta\lib\site-packages\pandas\core\indexes\base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
# ...

# %%
Social_support_Mean = Social_support_df.mean()
Social_support_Mean
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_1384\1518306078.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Social_support_Mean = Social_support_df.mean()
# Explained by: Social support    0.905863
# dtype: float64

# %%
Social_support_Flipped_df = Social_support_df.set_index("Country").T
Social_support_Flipped_df
# Out:
# Country                       Finland  Denmark  Iceland  Switzerland  \
# Explained by: Social support    1.258    1.243     1.32        1.226
#
# Country                       Netherlands  Luxembourg*  Sweden  Norway  \
# Explained by: Social support        1.206        1.155   1.204   1.239
#
# Country                       Israel  New Zealand  ...  Malawi  Tanzania  \
# Explained by: Social support   1.221        1.235  ...   0.279     0.597
#
# Country                       Sierra Leone  Lesotho*  Botswana*  Rwanda*  \
# Explained by: Social support         0.416     0.848      0.815    0.133
#
# Country                       Zimbabwe  Lebanon  Afghanistan  xx
# Explained by: Social support      0.69    0.498          0.0 NaN
#
# [1 rows x 147 columns]

# %%
Social_support_mean = Social_support_Flipped_df.mean()
Social_support_mean
# Out:
# Country
# Finland        1.258
# Denmark        1.243
# Iceland        1.320
# Switzerland    1.226
# Netherlands    1.206
#                ...
# Rwanda*        0.133
# Zimbabwe       0.690
# Lebanon        0.498
# Afghanistan    0.000
# xx               NaN
# Length: 147, dtype: float64

# %%
c_twentytwentytwo_sum = Social_support_df["Explained by: Social support"].sum()
c_count = Social_support_df["Country"].count()
c_total_mean = (c_twentytwentytwo_sum/(c_count*5))
c_total_mean
# Out:
# 0.17994013605442177

# %%
Happiness_Score_df = original_df[["Country", "Happiness score"]]
Happiness_Score_df.head()
# Out:
#        Country  Happiness score
# 0      Finland            7.821
# 1      Denmark            7.636
# 2      Iceland            7.557
# 3  Switzerland            7.512
# 4  Netherlands            7.415

# %%
Happiness_Year_Mean = Happiness_Score_df.mean()
Happiness_Year_Mean
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_1384\3422408629.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Happiness_Year_Mean = Happiness_Score_df.mean()
# Happiness score    5.553575
# dtype: float64

# %%
Happiness_Score_Flipped_df = Happiness_Score_df.set_index("Country").T
Happiness_Score_Flipped_df
# Out:
# Country          Finland  Denmark  Iceland  Switzerland  Netherlands  \
# Happiness score    7.821    7.636    7.557        7.512        7.415
#
# Country          Luxembourg*  Sweden  Norway  Israel  New Zealand  ...  \
# Happiness score        7.404   7.384   7.365   7.364          7.2  ...
#
# Country          Malawi  Tanzania  Sierra Leone  Lesotho*  Botswana*  Rwanda*  \
# Happiness score    3.75     3.702         3.574     3.512      3.471    3.268
#
# Country          Zimbabwe  Lebanon  Afghanistan  xx
# Happiness score     2.995    2.955        2.404 NaN
#
# [1 rows x 147 columns]

# %%
Happiness_Score_mean = Happiness_Score_Flipped_df.mean()
Happiness_Score_mean
# Out:
# Country
# Finland        7.821
# Denmark        7.636
# Iceland        7.557
# Switzerland    7.512
# Netherlands    7.415
#                ...
# Rwanda*        3.268
# Zimbabwe       2.995
# Lebanon        2.955
# Afghanistan    2.404
# xx               NaN
# Length: 147, dtype: float64

# %%
h_twentytwentytwo_sum = Happiness_Score_df["Explained by: Social support"].sum()
h_count = Happiness_Score_df["Country"].count()
h_total_mean = (c_twentytwentytwo_sum/(c_count*5))
h_total_mean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 h_twentytwentytwo_sum = Happiness_Score_df["Explained by: Social support"].sum()
#       2 h_count = Happiness_Score_df["Country"].count()
#       3 h_total_mean = (c_twentytwentytwo_sum/(c_count*5))
#
# NameError: name 'Happiness_Score_df' is not defined

# %%
country_name = family_score_df["Country"].unique()
country_mean = family_Flipped_df.mean()
country_mean_df = pd.DataFrame({"Social_support_mean": country_mean,
                                "Happiness score Mean": Happiness_Score_mean})
country_mean_df = country_mean_df.sort_values("Social_support_mean", ascending=False)
country_mean_df.head(10)
# Out:
#              Social_support_mean  Happiness score Mean
# Country
# Iceland                 1.492813                 7.557
# Denmark                 1.447688                 7.636
# Ireland                 1.445056                 7.041
# New Zealand             1.439729                 7.200
# Finland                 1.434429                 7.821
# Uzbekistan              1.434100                 6.063
# Norway                  1.431075                 7.365
# Switzerland             1.417332                 7.512
# Australia               1.409006                 7.162
# Spain                   1.399466                 6.476

# %%
def linear_regrression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-value is: {rvalue**2}")
    plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
    return line_eq

# %%
avg_country_plot = linear_regrression(country_mean_df["Happiness score Mean"], country_mean_df["Social_support_mean"])
plt.title("Social Support Influencing Happiness (2022)")
plt.xlabel("Happiness Score")
plt.ylabel("Social Support Influence")
plt.savefig("Figure_File/Social_support.png")
plt.show()
# Out:
# <div id='1ecb05cd-f1b4-431a-990d-bf3d64208591'></div>
# The r-value is: nan
