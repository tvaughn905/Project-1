# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
import json
from scipy import stats

# Store filepath in a variable
file = "Output_data/Happiness_df.csv"

# %%
original_df = pd.read_csv(file)
original_df.head()
# Out:
#    Index      Country  Rank (2015)  Happiness Score (2015)  Family (2015)  \
# 0      0  Switzerland          1.0                   7.587        1.34951
# 1      1      Iceland          2.0                   7.561        1.40223
# 2      2      Denmark          3.0                   7.527        1.36058
# 3      3       Norway          4.0                   7.522        1.33095
# 4      4       Canada          5.0                   7.427        1.32261
#
#    Health (2015)  Freedom (2015)  Perceptions of Corruption (2015)  \
# 0        0.94143         0.66557                           0.41978
# 1        0.94784         0.62877                           0.14145
# 2        0.87464         0.64938                           0.48357
# 3        0.88521         0.66973                           0.36503
# 4        0.90563         0.63297                           0.32957
#
#    Generosity (2015)  Rank (2016)  ...  Freedom (2019)  \
# 0            0.29678          2.0  ...           0.572
# 1            0.43630          3.0  ...           0.591
# 2            0.34139          1.0  ...           0.592
# 3            0.34699          4.0  ...           0.603
# 4            0.45811          6.0  ...           0.584
#
#    Perceptions of Corruption (2019)  Generosity (2019)  Rank (2022)  \
# 0                             0.343              0.263          4.0
# 1                             0.118              0.354          3.0
# 2                             0.410              0.252          2.0
# 3                             0.341              0.271          8.0
# 4                             0.308              0.285         15.0
#
#    Happiness Score (2022)  Family (2022)  Health (2022)  Freedom (2022)  \
# 0                   7.512          1.226          0.822           0.677
# 1                   7.557          1.320          0.803           0.718
# 2                   7.636          1.243          0.777           0.719
# 3                   7.365          1.239          0.786           0.728
# 4                   7.025          1.188          0.783           0.659
#
#    Perceptions of Corruption (2022)  Generosity (2022)
# 0                             0.461              0.147
# 1                             0.191              0.270
# 2                             0.532              0.188
# 3                             0.474              0.217
# 4                             0.368              0.217
#
# [5 rows x 44 columns]

# %%
family_score_df = original_df[["Country", "Family (2015)", "Family (2016)",
                     "Family (2017)", "Family (2018)",
                     "Family (2019)"]]
family_score_df.head()
# Out:
#        Country  Family (2015)  Family (2016)  Family (2017)  Family (2018)  \
# 0  Switzerland        1.34951        1.14524       1.516912          1.549
# 1      Iceland        1.40223        1.18326       1.610574          1.644
# 2      Denmark        1.36058        1.16374       1.551122          1.590
# 3       Norway        1.33095        1.12690       1.533524          1.582
# 4       Canada        1.32261        1.09610       1.481349          1.532
#
#    Family (2019)
# 0          1.526
# 1          1.624
# 2          1.573
# 3          1.582
# 4          1.505

# %%
family_Mean = family_score_df.mean()
family_Mean
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_7012\2852130667.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   family_Mean = family_score_df.mean()
# Family (2015)    1.016806
# Family (2016)    0.819735
# Family (2017)    1.226296
# Family (2018)    1.258879
# Family (2019)    1.258879
# dtype: float64

# %%
family_Flipped_df = family_score_df.set_index("Country").T
family_Flipped_df
# Out:
# Country        Switzerland   Iceland   Denmark    Norway    Canada   Finland  \
# Family (2015)     1.349510  1.402230  1.360580  1.330950  1.322610  1.318260
# Family (2016)     1.145240  1.183260  1.163740  1.126900  1.096100  1.134640
# Family (2017)     1.516912  1.610574  1.551122  1.533524  1.481349  1.540247
# Family (2018)     1.549000  1.644000  1.590000  1.582000  1.532000  1.592000
# Family (2019)     1.526000  1.624000  1.573000  1.582000  1.505000  1.587000
#
# Country        Netherlands    Sweden  New Zealand  Australia  ...   Senegal  \
# Family (2015)     1.280170  1.289070     1.319670   1.309230  ...  0.976190
# Family (2016)     1.029120  1.087640     1.172780   1.104760  ...  0.774160
# Family (2017)     1.428939  1.478162     1.548195   1.510042  ...  1.179692
# Family (2018)     1.488000  1.501000     1.601000   1.573000  ...  1.117000
# Family (2019)     1.522000  1.487000     1.557000   1.548000  ...  1.134000
#
# Country          Gabon  Cambodia  Tanzania    Guinea  Ivory Coast  \
# Family (2015)  0.90528  0.627360   1.00268  0.464750      0.77115
# Family (2016)  0.72368  0.537500   0.77623  0.310900      0.57576
# Family (2017)  1.15562  1.006238   1.04199  0.791245      0.90478
# Family (2018)  1.16400  1.088000   0.99100  0.792000      0.87200
# Family (2019)  1.18300  1.122000   0.88500  0.829000      0.80800
#
# Country        Burkina Faso  Afghanistan    Benin      Togo
# Family (2015)       0.85188     0.302850  0.35386  0.139950
# Family (2016)       0.63054     0.110370  0.10419  0.000000
# Family (2017)       1.04328     0.581543  0.43530  0.431883
# Family (2018)       1.09700     0.537000  0.37200  0.474000
# Family (2019)       1.05600     0.517000  0.43700  0.572000
#
# [5 rows x 116 columns]

# %%
family_score_mean = family_Flipped_df.mean()
family_score_mean
# Out:
# Country
# Switzerland     1.417332
# Iceland         1.492813
# Denmark         1.447688
# Norway          1.431075
# Canada          1.387412
#                   ...
# Ivory Coast     0.786338
# Burkina Faso    0.935740
# Afghanistan     0.409753
# Benin           0.340470
# Togo            0.323567
# Length: 116, dtype: float64

# %%
c_fifteen_sum = family_score_df["Family (2015)"].sum()
c_sixteen_sum = family_score_df["Family (2016)"].sum()
c_seventeen_sum = family_score_df["Family (2017)"].sum()
c_eighteen_sum = family_score_df["Family (2018)"].sum()
c_nineteen_sum = family_score_df["Family (2019)"].sum()
c_count = family_score_df["Country"].count()
c_total_mean = (c_fifteen_sum+c_sixteen_sum+c_seventeen_sum+c_eighteen_sum+c_nineteen_sum)/(c_count*5)
c_total_mean
# Out:
# 1.1161192752337292

# %%
Happiness_Score_df = original_df[["Country", "Happiness Score (2015)", "Happiness Score (2016)",
                     "Happiness Score (2017)", "Happiness Score (2018)",
                     "Happiness Score (2019)"]]
Happiness_Score_df.head()
# Out:
#        Country  Happiness Score (2015)  Happiness Score (2016)  \
# 0  Switzerland                   7.587                   7.509
# 1      Iceland                   7.561                   7.501
# 2      Denmark                   7.527                   7.526
# 3       Norway                   7.522                   7.498
# 4       Canada                   7.427                   7.404
#
#    Happiness Score (2017)  Happiness Score (2018)  Happiness Score (2019)
# 0                   7.494                   7.487                   7.480
# 1                   7.504                   7.495                   7.494
# 2                   7.522                   7.555                   7.600
# 3                   7.537                   7.594                   7.554
# 4                   7.316                   7.328                   7.278

# %%
Happiness_Year_Mean = Happiness_Score_df.mean()
Happiness_Year_Mean
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_7012\3422408629.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Happiness_Year_Mean = Happiness_Score_df.mean()
# Happiness Score (2015)    5.514328
# Happiness Score (2016)    5.525414
# Happiness Score (2017)    5.541164
# Happiness Score (2018)    5.576888
# Happiness Score (2019)    5.613086
# dtype: float64

# %%
Happiness_Score_Flipped_df = Happiness_Score_df.set_index("Country").T
Happiness_Score_Flipped_df
# Out:
# Country                 Switzerland  Iceland  Denmark  Norway  Canada  \
# Happiness Score (2015)        7.587    7.561    7.527   7.522   7.427
# Happiness Score (2016)        7.509    7.501    7.526   7.498   7.404
# Happiness Score (2017)        7.494    7.504    7.522   7.537   7.316
# Happiness Score (2018)        7.487    7.495    7.555   7.594   7.328
# Happiness Score (2019)        7.480    7.494    7.600   7.554   7.278
#
# Country                 Finland  Netherlands  Sweden  New Zealand  Australia  \
# Happiness Score (2015)    7.406        7.378   7.364        7.286      7.284
# Happiness Score (2016)    7.413        7.339   7.291        7.334      7.313
# Happiness Score (2017)    7.469        7.377   7.284        7.314      7.284
# Happiness Score (2018)    7.632        7.441   7.314        7.324      7.272
# Happiness Score (2019)    7.769        7.488   7.343        7.307      7.228
#
# Country                 ...  Senegal  Gabon  Cambodia  Tanzania  Guinea  \
# Happiness Score (2015)  ...    3.904  3.896     3.819     3.781   3.656
# Happiness Score (2016)  ...    4.219  4.121     3.907     3.666   3.607
# Happiness Score (2017)  ...    4.535  4.465     4.168     3.349   3.507
# Happiness Score (2018)  ...    4.631  4.758     4.433     3.303   3.964
# Happiness Score (2019)  ...    4.681  4.799     4.700     3.231   4.534
#
# Country                 Ivory Coast  Burkina Faso  Afghanistan  Benin   Togo
# Happiness Score (2015)        3.655         3.587        3.575  3.340  2.839
# Happiness Score (2016)        3.916         3.739        3.360  3.484  3.303
# Happiness Score (2017)        4.180         4.032        3.794  3.657  3.495
# Happiness Score (2018)        4.671         4.424        3.632  4.141  3.999
# Happiness Score (2019)        4.944         4.587        3.203  4.883  4.085
#
# [5 rows x 116 columns]

# %%
Happiness_Score_mean = Happiness_Score_Flipped_df.mean()
Happiness_Score_mean
# Out:
# Country
# Switzerland     7.5114
# Iceland         7.5110
# Denmark         7.5460
# Norway          7.5410
# Canada          7.3506
#                  ...
# Ivory Coast     4.2732
# Burkina Faso    4.0738
# Afghanistan     3.5128
# Benin           3.9010
# Togo            3.5442
# Length: 116, dtype: float64

# %%
h_fifteen_sum = Happiness_Score_df["Happiness Score (2015)"].sum()
h_sixteen_sum = Happiness_Score_df["Happiness Score (2016)"].sum()
h_seventeen_sum = Happiness_Score_df["Happiness Score (2017)"].sum()
h_eighteen_sum = Happiness_Score_df["Happiness Score (2018)"].sum()
h_nineteen_sum = Happiness_Score_df["Happiness Score (2019)"].sum()
h_count = Happiness_Score_df["Country"].count()
h_total_mean = (h_fifteen_sum+h_sixteen_sum+h_seventeen_sum+h_eighteen_sum+h_nineteen_sum)/(h_count*5)
h_total_mean
# Out:
# 5.554175861411259

# %%
country_name = family_score_df["Country"].unique()
country_mean = family_Flipped_df.mean()
country_mean_df = pd.DataFrame({"Family Mean": country_mean,
                                "Happiness Score Mean": Happiness_Score_mean})
country_mean_df = country_mean_df.sort_values("Family Mean", ascending=False)
country_mean_df.head(10)
# Out:
#              Family Mean  Happiness Score Mean
# Country
# Iceland         1.492813                7.5110
# Denmark         1.447688                7.5460
# Ireland         1.445056                6.9644
# New Zealand     1.439729                7.3130
# Finland         1.434429                7.5378
# Uzbekistan      1.434100                6.0462
# Norway          1.431075                7.5410
# Switzerland     1.417332                7.5114
# Australia       1.409006                7.2762
# Spain           1.399466                6.3514

# %%
def linear_regrression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))
    plt.scatter(x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-value is: {rvalue**2}")
    plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
    return line_eq

# %%
avg_country_plot = linear_regrression(country_mean_df["Happiness Score Mean"], country_mean_df["Family Mean"])
plt.title("Average of Family Influencing Happiness (2015-2019)")
plt.xlabel("Average Happiness Score")
plt.ylabel("Average Family Influence")
plt.savefig("Figure_File/Family.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-value is: 0.5852636004828335
